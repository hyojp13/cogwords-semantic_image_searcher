# %%
import pickle
import numpy as np
import mygrad
from PIL import Image
from embedding import create_embedding
import os
from database import database
from embedding import create_embeddings
import pickle
import shutil

# %%
with open("./img_weights.pkl", mode="rb") as iw:
    img_weights = pickle.load(iw)

# %%
from database import database
from embedding import create_embeddings
db = database("/Users/KittyKat/BWSI/BWSI-program/Week-3/captions_train2014.json")

# %%
import pickle
with open('/Users/KittyKat/BWSI/BWSI-program/Week-3/cogwords/cogwords/glove.pkl', 'rb') as l:
    glove = pickle.load(l)
# Out:
# /opt/anaconda3/envs/BWSI-week3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
from embedding import create_embedding
db.store_word_embeddings(img_weights)
caption = "horses on the beach"
embedding = create_embedding(caption, db.coco_data, glove)
IDs = db.query(embedding, k=4)

# %%
for id in IDs:
    db.display_image(id)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7FE18CB58E20>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=427x640 at 0x7FE18F2B6190>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7FE18F2B6550>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7FE18F2B6400>

# %%
db.store_word_embeddings(img_weights)

# %%
from PIL import Image
from embedding import create_embedding
import os

def find_images(caption, k):
    embedding = create_embedding(caption, db.coco_data, glove)
    IDs = db.query(embedding, k=k)
    for id in IDs:
        os.mkdir("./pics")
        img = db.display_image(id)
        img.save(f"./pics/{str(id)}.png")

# %%
find_images("horses on the beach", 2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7FFD283A40A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424 at 0x7FFD283A4160>

# %%
def delete_imgs():
    shutil.rmtree("./pics")

# %%
import os 
os.mkdir("./pics")

# %%
import shutil
shutil.rmtree("./pics")
